# %%
import pandas as pd

arquivo = pd.read_csv("data.csv")

#print(arquivo.to_string()) neste caso é melhor ler o dataframe diretamente
arquivo.head(30)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1260\2024827612.py in <module>
# ----> 1 import pandas as pd
#       2
#       3 arquivo = pd.read_csv('ocorrencia.csv',sep=";")
#       4
#       5 #print(arquivo.to_string()) neste caso é melhor ler o dataframe diretamente
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# O arquivo original tem 5167 colunas, irei diminuir as linhas vazias com este comando
novo_arquivo = arquivo.dropna()

novo_arquivo.head(30)

# Substituindo as linhas as celulas vazias com o fillna()
#novo_arquivo.fillna(120, inplace = True)
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1               45331               45331               45331
# 4               45407               45407               45407
# 6               50713               50713               50713
# 10              45332               45332               45332
# 12              45396               45396               45396
# 13              45408               45408               45408
# 18              50714               50714               50714
# 19              45399               45399               45399
# 21              45392               45392               45392
# 22              45390               45390               45390
# 24              45582               45582               45582
# 25              45400               45400               45400
# 29              45393               45393               45393
# 30              45397               45397               45397
# ...

# %%
#Substituindo as linhas as celulas vazias com o fillna()
#novo_arquivo.fillna(120, inplace = True)
#novo_arquivo.head(30)
# Out:
# D:\Cobra\lib\site-packages\pandas\core\frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1               45331               45331               45331
# 4               45407               45407               45407
# 6               50713               50713               50713
# 10              45332               45332               45332
# 12              45396               45396               45396
# 13              45408               45408               45408
# 18              50714               50714               50714
# 19              45399               45399               45399
# 21              45392               45392               45392
# ...

# %%
#novo_arquivo['codigo_ocorrencia'].fillna(120, inplace = True)
#novo_arquivo.head(30)
# Out:
# D:\Cobra\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1               45331               45331               45331
# 4               45407               45407               45407
# 6               50713               50713               50713
# 10              45332               45332               45332
# 12              45396               45396               45396
# 13              45408               45408               45408
# 18              50714               50714               50714
# 19              45399               45399               45399
# 21              45392               45392               45392
# ...

# %%
x = novo_arquivo["ocorrencia_latitude"].mean()

novo_arquivo.loc[65, 'ocorrencia_latitude'] = x

novo_arquivo.head(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Cobra\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ...
