# %%
import pandas as pd

valores_ausentes = ["**", "###!", "####", "*****", "****", "NULL"]

arquivo = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values = valores_ausentes)

arquivo_dataframe = pd.DataFrame(arquivo)

arquivo_dataframe.head(50)

# filtro_uf = arquivo.ocorrencia_uf.isnull()

# filtro_uf.value_counts()
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
# 5               52243               52243               52243
# 6               50713               50713               50713
# 7               45334               45334               45334
# 8               45391               45391               45391
# 9               52244               52244               52244
# 10              45332               45332               45332
# 11              52245               52245               52245
# 12              45396               45396               45396
# 13              45408               45408               45408
# ...

# %%
filtro_aerodromo = arquivo.ocorrencia_aerodromo.isnull()

filtro_aerodromo.value_counts()
# Out:
# False    3262
# True     1905
# Name: ocorrencia_aerodromo, dtype: int64

# %%
#Filtro que irá criar um dataframe com as cidades onde as recomendações são maiores que 5
filtro_recomendacoes = arquivo.total_recomendacoes >= 5
arquivo.loc[filtro_recomendacoes, ["ocorrencia_cidade", "total_recomendacoes"]]
# Out:
#         ocorrencia_cidade  total_recomendacoes
# 80               MARITUBA                    9
# 316               BOITUVA                    7
# 541   ALMIRANTE TAMANDARÉ                    9
# 691        CAMPINA GRANDE                    5
# 844              BRASÍLIA                   11
# 890        RIO DE JANEIRO                    5
# 1081            SÃO PAULO                    5
# 1102       RIO DE JANEIRO                    6
# 1168             COTEGIPE                    7
# 1187               MUCUGÊ                    7
# 1269             TERESINA                    6
# 1494              GOIÂNIA                    6
# 1525             LUZIÂNIA                    6
# 1565                COARI                    6
# 1583                BELÉM                    5
# 1669               SANTOS                   13
# 1764             BRASÍLIA                    5
# 1874               TOLEDO                    6
# 1997          CARAPICUÍBA                    5
# ...

# %%
#Agora irei criar um filtro para buscar os incidentes graves no estado do Rio de janeiro
filtro_ocorrencia = arquivo.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_estado = arquivo.ocorrencia_uf == 'RJ'
arquivo.loc[filtro_ocorrencia & filtro_estado] #iremos criar um dataframe com as informações dos incidentes graves no Rio de Janeiro
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 30                45397               45397               45397
# 59                45580               45580               45580
# 205               45833               45833               45833
# 300               46043               46043               46043
# 381               46263               46263               46263
# 702               46919               46919               46919
# 874               47894               47894               47894
# 990               48881               48881               48881
# 1063              49511               49511               49511
# 1154              49935               49935               49935
# 1194              50097               50097               50097
# 1407              51019               51019               51019
# 1425              51020               51020               51020
# 1444              51024               51024               51024
# ...

# %%
#Agora irei criar um filtro para buscar os incidentes graves no estado do Rio de janeiro
filtro_ocorrencia = arquivo.ocorrencia_classificacao == 'INCIDENTE'
filtro_estado = arquivo.ocorrencia_uf == 'RJ'
arquivo.loc[filtro_ocorrencia | filtro_estado]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 5                 52243               52243               52243
# 7                 45334               45334               45334
# 9                 52244               52244               52244
# 11                52245               52245               52245
# ...                 ...                 ...                 ...
# 5157              80453               80453               80453
# 5160              80451               80451               80451
# 5161              80456               80456               80456
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  52242               52242                INCIDENTE
# ...

# %%
# O metodo isin retorna um dataframe com True ou False caso dos dados que queremos estejam contidos no dataframe
# Em nosso caso sempre será verdadeiro(True) quando os dados forem INCIDENTES GRAVES e INCIDENTE 
filtro_isin = arquivo.ocorrencia_classificacao.isin(["INCIDENTE GRAVE", "INCIDENTE"])
print(filtro_isin)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5162    False
# 5163    False
# 5164     True
# 5165     True
# 5166     True
# Name: ocorrencia_classificacao, Length: 5167, dtype: bool

# %%
filtro_isin = arquivo.ocorrencia_classificacao.isin(["INCIDENTE GRAVE", "INCIDENTE"])
filtro_cidade = arquivo.ocorrencia_uf == "SP"
arquivo.loc[filtro_isin & filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 5                 52243               52243               52243
# 6                 50713               50713               50713
# 28                52248               52248               52248
# 35                52054               52054               52054
# 36                52055               52055               52055
# ...                 ...                 ...                 ...
# 5134              80425               80425               80425
# 5143              80431               80431               80431
# 5157              80453               80453               80453
# 5158              80454               80454               80454
# 5161              80456               80456               80456
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 5                  52243               52243                INCIDENTE
# ...
